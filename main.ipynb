# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve

# %%
# Actual values
y_true = np.array([1,0,1,1,0,1,0,0,1,0])

# Model predicted probabilities
y_prob = np.array([0.9,0.2,0.8,0.7,0.3,0.6,0.4,0.1,0.85,0.05])

# %%
threshold = 0.5

y_pred = (y_prob >= threshold).astype(int)

print("Predicted:", y_pred)
# Out:
# Predicted: [1 0 1 1 0 1 0 0 1 0]

# %%
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

TN, FP, FN, TP = cm.ravel()

print("TN =", TN)
print("FP =", FP)
print("FN =", FN)
print("TP =", TP)
# Out:
# Confusion Matrix:
#  [[5 0]
#  [0 5]]
# TN = 5
# FP = 0
# FN = 0
# TP = 5

# %%
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

TPR = TP / (TP + FN)
print("TPR:", TPR)

FPR = FP / (FP + TN)
print("FPR:", FPR)
# Out:
# Accuracy: 1.0
# TPR: 1.0
# FPR: 0.0

# %%
p = 0.7

odds = p / (1 - p)
logit = np.log(odds)

print("Probability:", p)
print("Odds:", odds)
print("Logit:", logit)
# Out:
# Probability: 0.7
# Odds: 2.333333333333333
# Logit: 0.8472978603872034

# %%
fpr, tpr, thresholds = roc_curve(y_true, y_prob)

plt.plot(fpr, tpr)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()
